# %%
from radstats import environment
env = environment.get('trajectory/MISSION',0)
# Out:
#      TRate (krad/s)  SRate (krad/s)  GRate (krad/s)  Rate (krad/s)  \
# 0      9.534419e-06             0.0        0.000003       0.000012
# 1      1.222501e-05             0.0        0.000005       0.000018
# 2      1.601997e-05             0.0        0.000008       0.000024
# 3      2.224323e-05             0.0        0.000011       0.000033
# 4      3.127497e-05             0.0        0.000013       0.000045
# ..              ...             ...             ...            ...
# 100    1.029154e-06             0.0        0.000270       0.000271
# 101    1.132479e-06             0.0        0.000273       0.000274
# 102    1.159703e-06             0.0        0.000276       0.000277
# 103    1.131593e-06             0.0        0.000278       0.000280
# 104    8.099119e-07             0.0        0.000281       0.000282
#
#      TDose (krad)  SDose (krad)  GDose (krad)  Dose (krad)  TTID (krad)  \
# 0        0.000572           0.0      0.000161     0.000733     0.000572
# ...
